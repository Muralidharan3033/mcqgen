# %%
import os
import json
import pandas as pd
import traceback

# %%
from dotenv import  load_dotenv
load_dotenv()
# Out:
# True

# %%
Key =  os.getenv("api_key")

# %%
print(Key)
# Out:
# AIzaSyDS-WcJrBSv46pHKuVQflvVjLFoayBvdQI
